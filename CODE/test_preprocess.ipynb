# %%
import segmentation_utils
import matplotlib.pyplot as plt

# %% [markdown]
# ### Detect 4 Corner Squares

# %%
img_path = r"D:\autograde\IMG_1581_iter_0.jpg"

segmentation_utils.drawCornerContours(img_path)
# Out:
# 4

# %% [markdown]
# ### Fix perspective based on 4 Corner Squares

# %%
warped = segmentation_utils.four_point_transform(img_path)

plt.imshow(warped)

# %% [markdown]
# ### Detect 27 inner squares

# %%
segmentation_utils.drawSquareContours(warped)
# Out:
# 27

# %%
centroids = segmentation_utils.findSquareContourCentroid(warped) #centroid of 27 square contours
centroids
# Out:
# [(349, 2713),
#  (1624, 2712),
#  (670, 2710),
#  (1304, 2709),
#  (987, 2708),
#  (28, 1906),
#  (352, 1905),
#  (1941, 1903),
#  (513, 1904),
#  (671, 1903),
#  (1622, 1901),
#  (1463, 1901),
#  (1304, 1900),
#  (989, 1901),
#  (1942, 1505),
#  (512, 1505),
#  (28, 1505),
#  (988, 1504),
#  (1463, 1503),
#  (1944, 870),
#  (988, 871),
#  (30, 870),
#  (509, 869),
#  (1744, 821),
#  (1421, 819),
#  (1745, 203),
#  (1421, 202)]

# %%
cropped_images = segmentation_utils.segmentation_6_parts(warped)

# %%
plt.imshow(cropped_images[1])

# %%
plt.imshow(cropped_images[2])

# %%
plt.imshow(cropped_images[3])

# %%
plt.imshow(cropped_images[4])

# %%
plt.imshow(cropped_images[5])
